# %%
# !pip3 install pandas
# !pip3 install numpy
# !pip3 install matplotlib
# !pip3 install seaborn
# !pip3 install scipy

# %%
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as sts

# %%
data = pd.read_csv("data.csv", delimiter=",")
data
# Out:
#    y_first y_second  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0      NaN      NaN         NaN         NaN         NaN         NaN
# 1    1,842    1,278         NaN         NaN         NaN         NaN
# 2    0,693    0,242         NaN         NaN         NaN         NaN
# 3   -0,664    5,721         NaN         NaN         NaN         NaN
# 4    2,842    6,745         NaN         NaN         NaN         NaN
# ..     ...      ...         ...         ...         ...         ...
# 77     NaN      NaN         NaN         NaN         NaN         NaN
# 78     NaN      NaN         NaN         NaN         NaN         NaN
# 79     NaN      NaN         NaN         NaN         NaN         NaN
# 80     NaN      NaN         NaN         NaN         NaN         NaN
# 81     NaN      NaN         NaN         NaN         NaN         NaN
#
#     Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  ...    Unnamed: 24  \
# 0          NaN         NaN         NaN         NaN  ...            NaN
# ...

# %%
def plot_empirical_cdf(sample):
    hist, edges = np.histogram(sample, bins=len(sample))
    Y = hist.cumsum()
    for i in range(len(Y)):
        plt.plot([edges[i], edges[i+1]],[Y[i], Y[i]], c="blue")
    plt.show()

# %%
def create_plots(data):
    data = pd.to_numeric(data, errors='coerce').dropna()
    data = data[data < 20]
    global_data = data
    var = np.var(data)
    plt.figure(figsize=(16, 10), dpi=120)
    plt.title("График плотности ")
    sns.kdeplot(data, fill=True, color="dodgerblue", label="-")
    print("Количество данных: " + str(len(data)))
    var = np.var(data)
    print("Дисперсия: " + str(var))
    print("Среднеквадратичное отклонение: " + str(math.sqrt(var)))
    print("Математическое ожидание: " + str(np.average(data)))
    plt.legend()
    plt.figure(figsize=(16, 10), dpi=120)
    plot_empirical_cdf(data)
    plt.show()

# %%
data1 = data.y_first.apply(lambda x: str(x).replace(",", "."))
create_plots(data1)
# Out:
# Количество данных: 56
# Дисперсия: 3.3907568185586734
# Среднеквадратичное отклонение: 1.841400776191504
# Математическое ожидание: 1.2693035714285714

# %%
data1 = data.y_second.apply(lambda x: str(x).replace(",", "."))
create_plots(data1)
# Out:
# Количество данных: 57
# Дисперсия: 18.26271626962142
# Среднеквадратичное отклонение: 4.273489940273806
# Математическое ожидание: 3.0938947368421053
